# %% [markdown]
# # Modeling and Simulation in Python
#
# Chapter 8: Pharmacokinetics
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# If you want the figures to appear in the notebook, 
# and you want to interact with them, use
# %matplotlib notebook

# If you want the figures to appear in the notebook, 
# and you don't want to interact with them, use
# %matplotlib inline

# If you want the figures to appear in separate windows, use
# %matplotlib qt5

# tempo switch from one to another, you have to select Kernel->Restart

# %matplotlib notebook

from modsim import *

# %% [markdown]
# ### Data
#
# We have data from Pacini and Bergman (1986), "MINMOD: a computer program to calculate insulin sensitivity and pancreatic responsivity from the frequently sampled intravenous glucose tolerance test", *Computer Methods and Programs in Biomedicine*, 23: 113-122..

# %%
data = pd.read_csv('glucose_insulin.csv', index_col='time')
data
# Out:
#       glucose  insulin
# time
# 0          92       11
# 2         350       26
# 4         287      130
# 6         251       85
# 8         240       51
# 10        216       49
# 12        211       45
# 14        205       41
# 16        196       35
# 19        192       30
# 22        172       30
# 27        163       27
# 32        142       30
# 42        124       22
# 52        105       15
# 62         92       15
# 72         84       11
# 82         77       10
# 92         82        8
# 102        81       11
# 122        82        7
# 142        82        8
# 162        85        8
# 182        90        7

# %% [markdown]
# Here's what the glucose time series looks like.

# %%
plot(data.glucose, 'bo', label='glucose')
decorate(xlabel='Time (min)',
         ylabel='Concentration (mg/dL)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# And the insulin time series.

# %%
newfig()
plot(data.insulin, 'go', label='insulin')
decorate(xlabel='Time (min)',
         ylabel='Concentration ($\mu$U/mL)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# For the book, I put them in a single figure, using `subplot`

# %%
newfig()
subplot(2, 1, 1)
plot(data.glucose, 'bo', label='glucose')
decorate(ylabel='mg/dL')

subplot(2, 1, 2)
plot(data.insulin, 'go', label='insulin')
decorate(xlabel='Time (min)',
         ylabel='$\mu$U/mL')

#savefig('chap08-fig01.pdf')
# Out:
# <img src="data:image/png;base64,..." width="879.9999809265141">

# %% [markdown]
# ### Interpolation
#
# We have measurements of insulin concentration at discrete points in time, but we need to estimate it at intervening points.  We'll use `interpolate`, which is a wrapper for `scipy.interpolate.interp1d`

# %%
# %psource interpolate

# %% [markdown]
# The return value from `interpolate` is a function.

# %%
I = interpolate(data.insulin, kind='linear')

# %% [markdown]
# We can use the result, `I`, to estimate the insulin level at any point in time.

# %%
I(7)
# Out:
# array(68.0)

# %% [markdown]
# `I` can also take an array of time and return an array of estimates, which we can plot.

# %%
ts = linrange(0, 182, 2)
newfig()
plot(data.insulin, 'go', label='insulin data')
plot(ts, I(ts), color='green', label='interpolated')

decorate(xlabel='Time (min)',
         ylabel='Concentration ($\mu$U/mL)')

#savefig('chap08-fig02.pdf')
"""I added the argument for kind as cubic, and then again as linear. The cubic interpolation was a lot smoother 
and cleaner than the linear one."""
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 'I added the argument for kind as cubic, and then again as linear. The cubic interpolation was a lot smoother \nand cleaner than the linear one.'

# %% [markdown]
# **Exercise:** [Read the documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html) of `scipy.interpolate.interp1d`.  Pass a keyword argument to `interpolate` to specify one of the other kinds of interpolation, and run the code again to see what it looks like.

# %% [markdown]
# ### The glucose minimal model
#
# I'll cheat by starting with parameters that fit the data roughly; then we'll see how to improve them.

# %%
k1 = 0.03
k2 = 0.02
k3 = 1e-05
G0 = 290

# %% [markdown]
# To estimate basal levels, we'll use the concentrations at `t=0`.

# %%
Gb = data.glucose[0]
Ib = data.insulin[0]

# %% [markdown]
# In the initial conditions, `X(0)=0` and `G(0)=G0`, where `G0` is one of the parameters we'll choose.

# %%
init = State(G=G0, X=0)

# %% [markdown]
# Here's the system object with all parameters and the interpolation object `I`.

# %%
system = System(init=init, 
                k1=k1, k2=k2, k3=k3,
                I=I, Gb=Gb, Ib=Ib,
                t0=0, t_end=182, dt=2)

# %% [markdown]
# And here's the update function.  Using `unpack` to make the system variables accessible without using dot notation, which makes the translation of the differential equations more readable and checkable.

# %%
def update_func(state, t, system):
    """Updates the glucose minimal model.
    
    state: State object
    t: time in min
    system: System object
    
    returns: State object
    """
    G, X = state
    unpack(system)
        
    dGdt = -k1 * (G - Gb) - X*G
    dXdt = k3 * (I(t) - Ib) - k2 * X
    
    G += dGdt * dt
    X += dXdt * dt

    return State(G=G, X=X)

# %% [markdown]
# Before running the simulation, it is always a good idea to test the update function using the initial conditions.  In this case we can veryify that the results are at least qualitatively correct.

# %%
update_func(init, 0, system)
# Out:
# G    278.12
# X      0.00
# dtype: float64

# %% [markdown]
# Now run simulation is pretty much the same as it always is.

# %%
def run_simulation(system, update_func):
    """Runs a simulation of the system.
    
    Adds a TimeFrame to `system` as `results`
    
    system: System object
    update_func: function that updates state
    """
    unpack(system)
    
    frame = TimeFrame(columns=init.index)
    frame.loc[t0] = init
    ts = linrange(t0, t_end-dt, dt)
    
    for t in ts:
        frame.loc[t+dt] = update_func(frame.loc[t], t, system)
    
    system.results = frame

# %% [markdown]
# And here's how we run it.  `%time` is a Jupyter magic command that runs the function and reports its run time.

# %%
# %time run_simulation(system, update_func)
# Out:
# Wall time: 218 ms

# %% [markdown]
# The results are in a `TimeFrame object` with one column per state variable.

# %%
system.results
# Out:
#               G         X
# 0    290.000000  0.000000
# 2    278.120000  0.000000
# 4    266.952800  0.000300
# 6    256.295460  0.002668
# 8    245.070140  0.004041
# 10   233.905138  0.004680
# 12   223.201651  0.005252
# 14   212.984844  0.005722
# 16   203.288207  0.006093
# 18   194.133461  0.006330
# 20   185.547835  0.006490
# 22   177.526606  0.006610
# 24   170.048014  0.006726
# 26   163.077697  0.006813
# 28   156.590997  0.006872
# 30   150.563255  0.006929
# 32   144.962829  0.007008
# 34   139.753191  0.007108
# 36   134.901294  0.007172
# 38   130.392302  0.007201
# 40   126.210925  0.007197
# 42   122.341665  0.007161
# 44   118.769029  0.007094
# 46   115.477698  0.007003
# 48   112.451743  0.006887
# 50   109.675836  0.006747
# 52   107.135308  0.006585
# 54   104.816180  0.006402
# 56   102.705192  0.006226
# 58   100.784058  0.006057
# ..          ...       ...
# 124   86.390694  0.001095
# 126   86.538102  0.000973
# 128   86.697421  0.000858
# 130   86.866797  0.000750
# 132   87.044539  0.000648
# 134   87.229105  0.000552
# 136   87.419090  0.000462
# 138   87.613215  0.000377
# 140   87.810314  0.000298
# 142   88.009328  0.000224
# 144   88.209296  0.000155
# 146   88.409343  0.000089
# 148   88.609033  0.000026
# 150   88.807970 -0.000036
# 152   89.005799 -0.000094
# 154   89.202200 -0.000150
# 156   89.396887 -0.000204
# 158   89.589604 -0.000256
# 160   89.780123 -0.000306
# 162   89.968242 -0.000354
# 164   90.153784 -0.000400
# 166   90.336592 -0.000446
# 168   90.516892 -0.000492
# 170   90.694895 -0.000538
# 172   90.870797 -0.000585
# 174   91.044781 -0.000631
# 176   91.217018 -0.000678
# 178   91.387668 -0.000725
# 180   91.556880 -0.000772
# 182   91.724792 -0.000819
#
# [92 rows x 2 columns]

# %% [markdown]
# The following plot shows the results of the simulation along with the actual glucose data.

# %%
newfig()
subplot(2, 1, 1)

plot(system.results.G, 'b-', label='simulation')
plot(data.glucose, style='bo', label='glucose data')
decorate(ylabel='mg/dL')

subplot(2, 1, 2)

plot(system.results.X, style='g-', label='remote insulin')

decorate(xlabel='Time (min)', 
         ylabel='Arbitrary units')

savefig('chap08-fig03.pdf')
# Out:
# <img src="data:image/png;base64,..." width="879.9999809265141">
# Saving figure to file chap08-fig03.pdf

# %% [markdown]
# ### Numerical solution
#
# We can do the same thing using `odeint`.  Instead of an update function, we provide a slope function that just evaluates the right-hand side of the differential equations.  We don't have to do the update part; `odeint` does it for us.

# %%
def slope_func(state, t, system):
    """Computes derivatives of the glucose minimal model.
    
    state: State object
    t: time in min
    system: System object
    
    returns: derivatives of G and X
    """
    G, X = state
    unpack(system)
    
    dGdt = -k1 * (G - Gb) - X*G
    dXdt = k3 * (I(t) - Ib) - k2 * X
    
    return dGdt, dXdt

# %% [markdown]
# We can test the slope function with the initial conditions.

# %%
slope_func(init, 0, system)
# Out:
# (-5.9399999999999995, 0.0)

# %% [markdown]
# The `System` object we use with `run_odeint` is almost the same as the one we used with `run_simulation`, but instead of providing `t0`, `t_end`, and `dt`, we provide an array of times where we want to evaluate the solution.  In this case, we use `data.index`, so the results are evaluated at the same times as the measurements.

# %%
system2 = System(init=init, 
                k1=k1, k2=k2, k3=k3,
                I=I, Gb=Gb, Ib=Ib,
                ts=data.index)

# %% [markdown]
# `run_odeint` is a wrapper for `scipy.integrate.odeint`

# %%
# %psource run_odeint

# %% [markdown]
# Here's how we run it.

# %%
# %time run_odeint(system2, slope_func)
# Out:
# Wall time: 110 ms

# %% [markdown]
# And here are the results.

# %%
system2.results
# Out:
#                G         X
# time
# 0     290.000000  0.000000
# 2     278.441946  0.000148
# 4     267.246339  0.001463
# 6     255.791154  0.003294
# 8     244.385049  0.004280
# 10    233.385689  0.004877
# 12    222.875391  0.005391
# 14    212.883104  0.005807
# 16    203.432604  0.006108
# 19    190.311106  0.006378
# 22    178.430723  0.006560
# 27    161.141293  0.006767
# 32    146.627308  0.006957
# 42    124.272257  0.007043
# 52    109.125928  0.006436
# 62     99.310554  0.005632
# 72     93.102455  0.004786
# 82     89.434359  0.003872
# 92     87.498085  0.002986
# 102    86.712650  0.002313
# 122    86.844866  0.001199
# 142    88.356758  0.000232
# 162    90.136930 -0.000339
# 182    91.795663 -0.000810

# %% [markdown]
# Plotting the results from `run_simulation` and `run_odeint`, we can see that they are not very different.

# %%
newfig()
plot(system.results.G, 'r-')
plot(system2.results.G, 'b-')
plot(data.glucose, 'bo')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# The differences are usually less than 1% and always less than 2%.

# %%
diff = system.results - system2.results
percent_diff = diff / system2.results * 100
percent_diff.dropna()
# Out:
#             G           X
# 2   -0.115624 -100.000000
# 4   -0.109838  -79.488129
# 6    0.197156  -19.008861
# 8    0.280333   -5.584132
# 10   0.222571   -4.045820
# 12   0.146387   -2.574882
# 14   0.047791   -1.457351
# 16  -0.070980   -0.241936
# 22  -0.506705    0.770903
# 32  -1.135176    0.739019
# 42  -1.553518    1.669890
# 52  -1.824149    2.322664
# 62  -1.877001    1.900503
# 72  -1.764022    2.270604
# 82  -1.574539    2.091263
# 92  -1.346686    2.279411
# 102 -1.093100    0.658312
# 122 -0.676648    2.068862
# 142 -0.393212   -3.390112
# 162 -0.187146    4.346125
# 182 -0.077205    1.148839

# %% [markdown]
# **Exercise:** What happens to these errors if you run the simulation with a smaller value of `dt`?

# %% [markdown]
# ### Optimization

# %% [markdown]
# Now let's find the parameters that yield the best fit for the data.

# %%
k1 = 0.03
k2 = 2000
k3 = 1e-05
G0 = 290
#k2 was initially .02

# %% [markdown]
# Again, we'll get basal levels from the initial values.

# %%
Gb = data.glucose[0]
Ib = data.insulin[0]

# %% [markdown]
# And the slope function is the same.

# %%
def slope_func(state, t, system):
    """Computes derivatives of the glucose minimal model.
    
    state: State object
    t: time in min
    system: System object
    
    returns: derivatives of G and X
    """
    G, X = state
    unpack(system)
    
    dGdt = -k1 * (G - Gb) - X*G
    dXdt = k3 * (I(t) - Ib) - k2 * X
    
    return dGdt, dXdt

# %% [markdown]
# `make_system` takes the parameters and `DataFrame` and returns a `System` object.

# %%
def make_system(G0, k1, k2, k3, data):
    """Makes a System object with the given parameters.
    
    G0: initial blood glucose
    k1: rate parameter
    k2: rate parameter
    k3: rate parameter
    data: DataFrame
    
    returns: System object
    """
    init = State(G=G0, X=0)
    system = System(init=init, 
                    k1=k1, k2=k2, k3=k3,
                    Gb=Gb, Ib=Ib, 
                    I=interpolate(data.insulin),
                    ts=data.index)
    return system

# %% [markdown]
# `error_func` takes the parameters and actual data, makes a `System` object and runs it, then compares the results of the simulation to the data.  It returns an array of errors.

# %%
def error_func(params, data):
    """Computes an array of errors to be minimized.
    
    params: sequence of parameters
    data: DataFrame of values to be matched
    
    returns: array of errors
    """
    print(params)
    
    # make a System with the given parameters
    system = make_system(*params, data)
    
    # solve the ODE
    run_odeint(system, slope_func)
    
    # compute the difference between the model
    # results and actual data
    error = system.results.G - data.glucose
    return error.loc[8:]

# %% [markdown]
# When we call `error_func`, we provide a sequence of parameters as a single object.

# %%
params = G0, k1, k2, k3
params
# Out:
# (290, 0.03, 2000, 1e-05)

# %% [markdown]
# Here's how that works:

# %%
error_func(params, data)
# Out:
# (290, 0.03, 2000, 1e-05)
# time
# 8       7.751763
# 10     22.681403
# 12     19.139267
# 14     17.094597
# 16     18.518423
# 19     11.973342
# 22     22.335877
# 27     17.081229
# 32     25.812144
# 42     24.162911
# 52     28.606463
# 62     30.822806
# 72     30.834086
# 82     31.915909
# 92     22.531623
# 102    20.283661
# 122    15.094999
# 142    12.796221
# 162     8.534622
# 182     2.842244
# dtype: float64

# %% [markdown]
# `fit_leastsq` is a wrapper for `scipy.optimize.leastsq`

# %%
#%psource fit_leastsq

# %% [markdown]
# Here's how we call it.

# %%
best_params = fit_leastsq(error_func, params, data)
# Out:
# [  2.90000000e+02   3.00000000e-02   2.00000000e+03   1.00000000e-05]
# [  2.90000000e+02   3.00000000e-02   2.00000000e+03   1.00000000e-05]
# [  2.90000000e+02   3.00000000e-02   2.00000000e+03   1.00000000e-05]
# [  2.90000004e+02   3.00000000e-02   2.00000000e+03   1.00000000e-05]
# [  2.90000000e+02   3.00000004e-02   2.00000000e+03   1.00000000e-05]
# [  2.90000000e+02   3.00000000e-02   2.00000003e+03   1.00000000e-05]
# [  2.90000000e+02   3.00000000e-02   2.00000000e+03   1.00000001e-05]
# [  3.00037650e+02   3.15670089e-02   1.94274841e+03   9.29645335e-06]
# [  2.94341017e+02   3.07947990e-02   2.09218531e+03   9.74875114e-06]
# [  2.92153592e+02   3.03778936e-02   2.07693083e+03   9.93587542e-06]
# [  2.91077050e+02   3.01763149e-02   2.04516411e+03   9.98631107e-06]
# [  2.90533420e+02   3.00832998e-02   2.02375684e+03   9.99745563e-06]
# [  2.90275015e+02   3.00418894e-02   2.01255024e+03   9.99963692e-06]
# [  2.90137575e+02   3.00206664e-02   2.00635347e+03   1.00000570e-05]
# [  2.90067698e+02   3.00100965e-02   2.00314458e+03   1.00000859e-05]
# [  2.90029976e+02   3.00044531e-02   2.00139665e+03   1.00000516e-05]
# [  2.90014558e+02   3.00021592e-02   2.00067916e+03   1.00000277e-05]
# [  2.90007058e+02   3.00010460e-02   2.00032945e+03   1.00000141e-05]
# [  2.90003419e+02   3.00005065e-02   2.00015964e+03   1.00000070e-05]
# [  2.90001655e+02   3.00002451e-02   2.00007728e+03   1.00000034e-05]
# [  2.90000800e+02   3.00001185e-02   2.00003737e+03   1.00000017e-05]
# [  2.90000387e+02   3.00000574e-02   2.00001809e+03   1.00000008e-05]
# [  2.90000187e+02   3.00000276e-02   2.00000872e+03   1.00000004e-05]
# [  2.90000090e+02   3.00000133e-02   2.00000420e+03   1.00000002e-05]
# [  2.90000044e+02   3.00000064e-02   2.00000203e+03   1.00000001e-05]
# [  2.90000020e+02   3.00000030e-02   2.00000094e+03   1.00000000e-05]
# [  2.90000010e+02   3.00000015e-02   2.00000046e+03   1.00000000e-05]
# [  2.90000005e+02   3.00000007e-02   2.00000022e+03   1.00000000e-05]
# [  2.90000009e+02   3.00000007e-02   2.00000022e+03   1.00000000e-05]
# [  2.90000005e+02   3.00000011e-02   2.00000022e+03   1.00000000e-05]
# [  2.90000005e+02   3.00000007e-02   2.00000025e+03   1.00000000e-05]
# [  2.90000005e+02   3.00000007e-02   2.00000022e+03   1.00000002e-05]
# [  2.90000002e+02   3.00000003e-02   2.00000020e+03   1.00000004e-05]
# modsim.py: scipy.optimize.leastsq ran successfully
#                  and returned the following message:
# The relative error between two consecutive iterates is at most 0.000000

# %% [markdown]
# Now that we have `best_params`, we can use it to make a `System` object and run it.
#
# We have to use the scatter operator, `*`, to make `best_params` behave like four separate parameters, rather than a single object.

# %%
system = make_system(*best_params, data)
run_odeint(system, slope_func)

# %% [markdown]
# Here are the results, along with the data.  The first few points of the model don't fit the data, but we don't expect them to.

# %%
newfig()
plot(system.results.G, label='simulation')
plot(data.glucose, style='bo', label='glucose data')

decorate(xlabel='Time (min)',
         ylabel='Concentration (mg/dL)')

#savefig('chap08-fig04.pdf')
"""The change for the return value of error_func has been made. The graph is nicer now.
    It seems like the starting values can have a strong effect on what the final product looks like."""
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 'The change for the return value of error_func has been made. The graph is nicer now.\n    It seems like the starting values can have a strong effect on what the final product looks like.'

# %% [markdown]
# **Exercise:** Since we don't expect the first few points to agree, it's probably better not to make them part of the optimization process.  We can ignore them by leaving them out of the `Series` returned by `error_func`.  Modify the last line of `error_func` to return `errors.loc[8:]`, which includes only the elements of the `Series` from `t=8` and up.
#
# Does that improve the quality of the fit?  Does it change the best parameters by much?
#
# Note: You can read more about this use of `loc` [in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer).

# %% [markdown]
# **Exercise:** How sensitive are the results to the starting guess for the parameters.  If you try different values for the starting guess, do we get the same values for the best parameters?

# %% [markdown]
# ### Interpreting parameters
#
# Based on the parameters of the model, we can estimate glucose effectiveness and insulin sensitivity.

# %%
def indices(G0, k1, k2, k3):
    """Compute glucose effectiveness and insulin sensitivity.
    
    G0: initial blood glucose
    k1: rate parameter
    k2: rate parameter
    k3: rate parameter
    data: DataFrame
    
    returns: State object containing S_G and S_I
    """
    return State(S_G=k1, S_I=k3/k2)

# %% [markdown]
# Here are the results.

# %%
indices(*best_params)
# Out:
# S_G    3.000000e-02
# S_I    4.999999e-09
# dtype: float64

# %% [markdown]
# ### The insulin minimal model
#
# In addition to the glucose minimal mode, Pacini and Bergman present an insulin minimal model, in which the concentration of insulin, $I$, is governed by this differential equation:
#
# $ \frac{dI}{dt} = -k I(t) + \gamma (G(t) - G_T) t $

# %% [markdown]
# **Exercise:**  Write a version of `make_system` that takes the parameters of this model, `I0`, `k`, `gamma`, and `G_T` as parameters, along with a `DataFrame` containing the measurements, and returns a `System` object suitable for use with `run_simulation` or `run_odeint`.
#
# Use it to make a `System` object with the following parameters:

# %%
"""Why did the other model need two variables in its state whereas this one needs only one? 
Also, I relied a bit heavily on the solutions guide for understanding this part."""

I0 = 360
k = 0.25
gamma = 0.004
G_T = 80

def make_system(I0,k,gamma,G_T,data):
    
    init=State(I=I0)
    system= System(init=init,
                  k=k, gamma=gamma,
                  G_T=G_T, G=interpolate(data.glucose),
                  ts=data.index)
    
    return system

# %%
# Solution goes here
#print(data)"

# %%
# Solution goes here

# %% [markdown]
# **Exercise:** Write a slope function that takes state, t, system as parameters and returns the derivative of `I` with respect to time.  Test your function with the initial condition $I(0)=360$.

# %%
# Solution goes here

def slope_func(state,t,system):
    I = state
    unpack(system)
    
    dIdt = -k*I + gamma*(G(t)-G_T)*t
    
    return dIdt

#Here is the tesing of the code

system=make_system(I0=360,k=0.25,gamma=0.004,G_T=80,data=data)

slope_func(init,90,system)
# Out:
# I   -89.64
# dtype: float64

# %% [markdown]
# #Solution goes here
#
#             """This is here for reference."""
#
#
# def slope_func(state, t, system):
#     """Computes derivatives of the glucose minimal model.
#
#     state: State object
#     t: time in min
#     system: System object
#
#     returns: derivatives of G and X
#     """
#     G, X = state
#     unpack(system)
#
#     dGdt = -k1 * (G - Gb) - X*G
#     dXdt = k3 * (I(t) - Ib) - k2 * X
#
#     return dGdt, dXdt

# %% [markdown]
# **Exercise:** Run `run_odeint` with your `System` object and slope function, and plot the results, along with the measured insulin levels.

# %%
# Solution goes here

run_odeint(system,slope_func)
newfig()
plot(data.insulin, "ro", label="Data")
plot(system.results, label="Function")
decorate(xlabel='Time',
         ylabel='Concentration',
         legend=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Solution goes here

# %% [markdown]
# **Exercise:**  Write an error function that takes a sequence of parameters as an argument, along with the `DataFrame` containing the measurements.  It should make a `System` object with the given parameters, run it, and compute the difference between the results of the simulation and the measured values.  Test your error function by calling it with the parameters from the previous exercise.
#
# Hint: As we did in a previous exercise, you might want to drop the errors for times prior to `t=8`.

# %%
# Solution goes here

def error_func(params, data):
    
    system=make_system(*params, data=data)
    
    run_odeint(system,slope_func)
    
    error=system.results.I-data.index
    
    return error.loc[8:]

# %%
# Solution goes here

params = [I0, k, gamma, G_T]
error_func(params, data=data)
# Out:
# time
# 8       53.636133
# 10      35.765330
# 12      25.053121
# 14      18.989732
# 16      15.406589
# 19      12.811071
# 22      10.581632
# 27       7.014287
# 32       1.758216
# 42     -11.067098
# 52     -27.445784
# 62     -46.232196
# 72     -64.217947
# 82     -82.382598
# 92     -91.401702
# 102   -100.056569
# 122   -118.584244
# 142   -137.586427
# 162   -150.829749
# 182   -156.297301
# Name: I, dtype: float64

# %%
# Solution goes here

# %% [markdown]
# **Exercise:** Use `fit_leastsq` to find the parameters that best fit the data.  Make a `System` object with those parameters, run it, and plot the results along with the measurements.

# %%
# Solution goes here

best_params=fit_leastsq(error_func,params,data)
# Out:
# modsim.py: scipy.optimize.leastsq ran successfully
#                  and returned the following message:
# The relative error between two consecutive iterates is at most 0.000000

# %%
# Solution goes here

# %%
# Solution goes here

# %%
# Solution goes here

# %% [markdown]
# **Exercise:** Using the best parameters, estimate the sensitivity to glucose of the first and second phase pancreatic responsivity:
#
# $ \phi_1 = \frac{I_{max} - I_b}{k (G_0 - G_b)} $
#
# $ \phi_2 = \gamma \times 10^4 $

# %%
# Solution goes here
I_max = data.insulin.max()
Ib=data.insulin[0]
Gb=data.glucose[0]

phi_1=I_max-Ib/(k*(G0-Gb))
phi_1
# Out:
# 129.85342143081644

# %%
# Solution goes here

phi_2=gamma*10**4
phi_2
# Out:
# 75.555849848440673

# %%
# Solution goes here

# %%
# Solution goes here
