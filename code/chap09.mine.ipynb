# %% [markdown]
# # Modeling and Simulation in Python
#
# Chapter 9: Projectiles
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# If you want the figures to appear in the notebook, 
# and you want to interact with them, use
# %matplotlib notebook

# If you want the figures to appear in the notebook, 
# and you don't want to interact with them, use
# %matplotlib inline

# If you want the figures to appear in separate windows, use
# %matplotlib qt5

# tempo switch from one to another, you have to select Kernel->Restart

# %matplotlib notebook

from modsim import *

# %% [markdown]
# ### Dropping pennies
#
# I'll start by getting the units we'll need from Pint.

# %%
m = UNITS.meter
s = UNITS.second
kg = UNITS.kilogram

# %% [markdown]
# And defining the initial state.

# %%
init = State(y=381 * m, 
             v=0 * m/s)
init
# Out:
# y             381 meter
# v    0.0 meter / second
# dtype: object

# %% [markdown]
# Acceleration due to gravity is about 9.8 m / s$^2$.

# %%
g = 9.8 * m/s**2

# %% [markdown]
# When we call `odeint`, we need an array of timestamps where we want to compute the solution.
#
# I'll start with a duration of 10 seconds.

# %%
duration = 10 * s
ts = linspace(0, duration, 2)
ts
# Out:
# <Quantity([  0.  10.], 'second')>

# %% [markdown]
# Now we make a `System` object.

# %%
system = System(init=init, g=g, ts=ts)

# %% [markdown]
# And define the slope function.

# %%
def slope_func(state, t, system):
    """Compute derivatives of the state.
    
    state: position, velocity
    t: time
    system: System object containing `g`
    
    returns: derivatives of y and v
    """
    
    y, v = state
    unpack(system)    

    dydt = v
    dvdt = -g
    #print(t)
    return dydt, dvdt

# %% [markdown]
# It's always a good idea to test the slope function with the initial conditions.

# %%
dydt, dvdt = slope_func(init, 0, system)
print(dydt)
print(dvdt)
# Out:
# 0.0 meter / second
# -9.8 meter / second ** 2

# %% [markdown]
# Now we're ready to run `odeint`

# %%
run_odeint(system, slope_func)

# %% [markdown]
# Here's what the results look like.

# %%
system.results.head()
# Out:
#           y     v
# 0.0   381.0   0.0
# 10.0 -109.0 -98.0

# %%
system.results.tail()
# Out:
#           y     v
# 0.0   381.0   0.0
# 10.0 -109.0 -98.0

# %% [markdown]
# The following function plots the results.

# %%
def plot_position(results):
    """Plot the results.
    
    results: DataFrame with position, `y`
    """
    newfig()
    plot(results.y, label='y')
        
    decorate(xlabel='Time (s)',
             ylabel='Position (m)')

# %% [markdown]
# Here's what it looks like.

# %%
plot_position(system.results)
savefig('chap09-fig01.pdf')
#We can infer that odeint is using something similar to Newton's method to find roots.
#It can make em better or horrible. It changes how well python approximates
# Out:
# <img src="data:image/png;base64,..." width="640">
# Saving figure to file chap09-fig01.pdf

# %% [markdown]
# **Exercise:** Add a print statement to `slope_func` to print the value of `t` each time it's called.  What can we infer about how `odeint` works, based on the results?

# %% [markdown]
# **Exercise:** Change the value of `dt` and run the solver again.  What effect does it have on the results?

# %% [markdown]
# ### Onto the sidewalk
#
# Here's the code again to set up the `System` object.

# %%
def make_system(duration, v_init=10000):
    """Make a system object.
    
    duration: time of simulation in seconds
    v_init: initial velocity, dimensionless
    
    returns: System object
    """
    init = State(y=381 * m, v=v_init * m / s)

    g = 9.8 * m/s**2
    ts = linspace(0, duration, 11)
    
    return System(init=init, g=g, ts=ts)

# %% [markdown]
# And run the simulation.

# %%
system = make_system(10)
run_odeint(system, slope_func)
system.results
# Out:
#             y        v
# 0.0     381.0  10000.0
# 1.0   10376.1   9990.2
# 2.0   20361.4   9980.4
# 3.0   30336.9   9970.6
# 4.0   40302.6   9960.8
# 5.0   50258.5   9951.0
# 6.0   60204.6   9941.2
# 7.0   70140.9   9931.4
# 8.0   80067.4   9921.6
# 9.0   89984.1   9911.8
# 10.0  99891.0   9902.0

# %% [markdown]
# To figure out when the penny hit the sidewalk, we use `interp_inverse`, which return a function that maps from height to time.

# %%
y = system.results.y
T = interp_inverse(y, kind='cubic')

# %% [markdown]
# `T(0)` interpolates the time when the height was 0.

# %%
T_sidewalk = T(0)
T_sidewalk
# Out:
# array(-0.03809928884208111)

# %% [markdown]
# We can compare that to the exact result.  Without air resistance, we have
#
# $v = -g t$
#
# and
#
# $y = 381 - g t^2 / 2$
#
# Setting $y=0$ and solving for $t$ yields
#
# $t = \sqrt{\frac{2 y_{init}}{g}}$

# %%
sqrt(2 * init.y / g)
# Out:
# <Quantity(8.817885349720552, 'second')>

# %% [markdown]
# The estimate is accurate to 4 decimal places.

# %% [markdown]
# We can double-check by running the simulation for the estimated flight time.

# %%
system = make_system(duration=T_sidewalk)
run_odeint(system, slope_func)

# %% [markdown]
# And checking the final state.

# %%
def final_state(results):
    """Returns the final position and velocity, with units.
    
    results: TimeFrame with y and v.
    
    returns: y, v at t_end
    """
    t_end = results.index[-1]
    y, v = results.loc[t_end]
    return y*m, v*m/s

# %% [markdown]
# As expected, the final height is close to 0.

# %%
y_final, v_final = final_state(system.results)
y_final
# Out:
# <Quantity(-1.044283521878242e-06, 'meter')>

# %% [markdown]
# And we can check the final velocity.

# %%
v_final
# Out:
# <Quantity(10000.373373030654, 'meter / second')>

# %% [markdown]
# And convert to km/h

# %%
km = UNITS.kilometer
h = UNITS.hour
v_final.to(km / h)

"""Things go horribly wrong with larger velocities because when the function for y as a function of time is interpolated, the
function is a parabola with two roots. One root is where the penny actually hits the ground and the other is in some negative
time due to the nature of parabolas."""
# Out:
# <Quantity(-311.0965093320861, 'kilometer / hour')>

# %% [markdown]
# If there were no air resistance, the penny would hit the sidewalk (or someone's head) at more than 300 km/h.
#
# So it's a good thing there is air resistance.

# %% [markdown]
# **Exercise:** Try changing the initial velocity and see what effect it has on the time to hit the sidewalk.  Sweep a range of values for the initial velocity, from 0 to 25 m/s, and plot `T_sidewalk` as a function of initial velocity.  You might find the following function useful.
#
# Things might go horribly wrong for the larger initial velocities.  What's going on?

# %%
def flight_time(system):
    """Simulates the system and computes flight time.
    
    Uses cubic interpolation.
    
    system: System object
    
    returns: flight time in seconds
    """
    run_odeint(system, slope_func)
    y = system.results.y
    inverse = Series(y.index, index=y.values)
    T = interpolate(inverse, kind='cubic')
    T_sidewalk = T(0)
    return T_sidewalk * s

#reminder for what I'm working with
def make_system(duration, v_init=0):
    """Make a system object.
    
    duration: time of simulation in seconds
    v_init: initial velocity, dimensionless
    
    returns: System object
    """
    init = State(y=381 * m, v=v_init * m / s)

    g = 9.8 * m/s**2
    ts = linspace(0, duration, 11)
    
    return System(init=init, g=g, ts=ts)

# %%
# Solution goes here
newfig()

for init_v in linspace(0,100):
    system=make_system(1000,init_v)
    T_sidewalk=flight_time(system)
    plot(init_v, T_sidewalk, "r.")
    
"run_odeint is giving up before it can spit out an accurate guess"
# Out:
# <img src="data:image/png;base64,..." width="640">
# 'run_odeint is giving up before it can spit out an accurate guess'

# %% [markdown]
# ### With air resistance

# %% [markdown]
# Next we'll add air resistance using the [drag equation](https://en.wikipedia.org/wiki/Drag_equation)
#
# First I'll create a `Condition` object to contain the quantities we'll need.

# %%
condition = Condition(height = 381 * m,
                      v_init = 0 * m / s,
                      g = 9.8 * m/s**2,
                      mass = 2.5e-3 * kg,
                      diameter = 19e-3 * m,
                      rho = 1.2 * kg/m**3,
                      v_term = 18 * m / s,
                      duration = 30 * s)

# %% [markdown]
# Now here's a version of `make_system` that takes a `Condition` object as a parameter.
#
# `make_system` uses the given value of `v_term` to compute the drag coefficient `C_d`.

# %%
def make_system(condition):
    """Makes a System object for the given conditions.
    
    condition: Condition with height, g, mass, diameter, 
               rho, v_term, and duration
    
    returns: System with init, g, mass, rho, C_d, area, and ts
    """
    unpack(condition)
    
    init = State(y=height, v=v_init)
    area = np.pi * (diameter/2)**2
    C_d = 2 * mass * g / (rho * area * v_term**2)
    ts = linspace(0, duration, 101)
    
    return System(init=init, g=g, mass=mass, rho=rho,
                  C_d=C_d, area=area, ts=ts)

# %% [markdown]
# Let's make a `System`

# %%
system = make_system(condition)
system
# Out:
# init    y             381 meter
# v    0.0 meter / secon...
# g                                 9.8 meter / second ** 2
# mass                                      0.0025 kilogram
# rho                             1.2 kilogram / meter ** 3
# C_d                      0.4445009981135434 dimensionless
# area                     0.0002835287369864788 meter ** 2
# ts      [0.0 second, 0.3 second, 0.6 second, 0.8999999...
# dtype: object

# %% [markdown]
# Here's the slope function, including acceleration due to gravity and drag.

# %%
def slope_func(state, t, system):
    """Compute derivatives of the state.
    
    state: position, velocity
    t: time
    system: System object containing g, rho,
            C_d, area, and mass
    
    returns: derivatives of y and v
    """
    y, v = state
    unpack(system)
    
    f_drag = rho * v**2 * C_d * area / 2
    a_drag = f_drag / mass
    
    dydt = v
    dvdt = -g + a_drag
    
    return dydt, dvdt

# %% [markdown]
# As always, let's test the slope function with the initial conditions.

# %%
slope_func(system.init, 0, system)
# Out:
# (<Quantity(0.0, 'meter / second')>, <Quantity(-9.8, 'meter / second ** 2')>)

# %% [markdown]
# And then run the simulation.

# %%
run_odeint(system, slope_func)

# %% [markdown]
# First check that the simulation ran long enough for the penny to land.

# %%
final_state(system.results)
# Out:
# (<Quantity(-136.083704279796, 'meter')>,
#  <Quantity(-18.00000000087864, 'meter / second')>)

# %% [markdown]
# Then compute the flight time.

# %%
y = system.results.y
inverse = Series(y.index, index=y.values)
T = interpolate(inverse, kind='cubic')
T_sidewalk = T(0)
T_sidewalk
# Out:
# array(22.439794207078908)

# %% [markdown]
# Setting the duration to the computed flight time, we can check the final conditions.

# %%
condition.set(duration=T_sidewalk)
system = make_system(condition)
run_odeint(system, slope_func)
y_final, v_final = final_state(system.results)

# %% [markdown]
# The final height is close to 0, as expected.  And the final velocity is close to the given terminal velocity.

# %%
y_final, v_final
# Out:
# (<Quantity(1.2732392917769175e-10, 'meter')>,
#  <Quantity(-18.00000000874157, 'meter / second')>)

# %% [markdown]
# Here's the plot of position as a function of time.

# %%
plot_position(system.results)
#savefig('chap09-fig02.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# And velocity as a function of time:

# %%
def plot_velocity(results):
    """Plot the results.
    
    results: DataFrame with velocity, v
    """
    newfig()
    plot(results.v, label='v')
        
    decorate(xlabel='Time (s)',
             ylabel='Velocity (m/2)')

# %%
plot_velocity(system.results)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# From an initial velocity of 0, the penny accelerates downward until it reaches terminal velocity; after that, velocity is constant.

# %% [markdown]
# **Exercise:** Run the simulation with an initial velocity, downward, that exceeds the penny's terminal velocity.  Hint: use `condition.set`.
#
# What do you expect to happen?  Plot velocity and position as a function of time, and see if they are consistent with your prediction.

# %%
# Solution goes here

#troubleshooting stuff over here
def slope_func(state, t, system):
    """Compute derivatives of the state.
    
    state: position, velocity
    t: time
    system: System object containing g, rho,
            C_d, area, and mass
    
    returns: derivatives of y and v
    """
    y, v = state
    unpack(system)

    f_drag = rho * v**2 * C_d * area / 2
    #print("rho is",rho)
    #print("v is",v)
    #print("C_d is",C_d)
    #print("area is",area)
    #print("f_drag is",f_drag)
    
    a_drag = f_drag / mass
    
    dydt = v
    #print(-g)
    #print(a_drag)
    dvdt = -g + a_drag
    
    return dydt, dvdt

def make_system(condition):
    """Makes a System object for the given conditions.
    
    condition: Condition with height, g, mass, diameter, 
               rho, v_term, and duration
    
    returns: System with init, g, mass, rho, C_d, area, and ts
    """
    unpack(condition)
    
    init = State(y=height, v=v_init)
    area = np.pi * (diameter/2)**2
    C_d = 2 * mass * g / (rho * area * v_term**2)
    ts = linspace(0, duration, 101)
    
    return System(init=init, g=g, mass=mass, rho=rho,
                  C_d=C_d, area=area, ts=ts)

#Actual Solution

condition = Condition(height = 381 * m,
                      v_init = 0 * m / s,
                      g = 9.8 * m/s**2,
                      mass = 2.5e-3 * kg,
                      diameter = 19e-3 * m,
                      rho = 1.2 * kg/m**3,
                      v_term = 18 * m / s,
                      duration = 30 * s)


condition.set(v_init=-1000000000* m / s)
system = make_system(condition)
run_odeint(system, slope_func)
y_final, v_final = final_state(system.results)

plot_position(system.results)

plot_velocity(system.results)

"""The graphs stop making sense when the initial velocity of the penny exceeds its terminal velocity"""
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\scipy\integrate\odepack.py:218: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# Solution goes here

# %% [markdown]
# ### Dropping quarters

# %% [markdown]
# Suppose we drop a quarter from the Empire State Building and find that its flight time is 19.1 seconds.  We can use this measurement to estimate the coefficient of drag.
#
# Here's a `Condition` object with the relevant parameters from
# https://en.wikipedia.org/wiki/Quarter_(United_States_coin)

# %%
condition = Condition(height = 381 * m,
                      v_init = 0 * m / s,
                      g = 9.8 * m/s**2,
                      mass = 5.67e-3 * kg,
                      diameter = 24.26e-3 * m,
                      rho = 1.2 * kg/m**3,
                      duration = 19.1 * s)

# %% [markdown]
# And here's a modified version of `make_system`

# %%
def make_system(condition):
    """Makes a System object for the given conditions.
    
    condition: Condition with height, v_init, g, mass, diameter, 
               rho, C_d, and duration
    
    returns: System with init, g, mass, rho, C_d, area, and ts
    """
    unpack(condition)
    
    init = State(y=height, v=v_init)
    area = np.pi * (diameter/2)**2
    ts = linspace(0, duration, 101)
    
    return System(init=init, g=g, mass=mass, rho=rho,
                  C_d=C_d, area=area, ts=ts)

# %% [markdown]
# We can run the simulation with an initial guess of `C_d=0.4`.

# %%
condition.set(C_d=0.4)
system = make_system(condition)
run_odeint(system, slope_func)
plot_position(system.results)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The final height is -11 meters, which means our guess was too low (we need more drag to slow the quarter down).

# %%
final_state(system.results)
# Out:
# (<Quantity(-11.034779626277231, 'meter')>,
#  <Quantity(-22.380158694375393, 'meter / second')>)

# %% [markdown]
# `height_func` takes a hypothetical value of `C_d` and returns the height after 19.1 seconds.

# %%
def height_func(C_d, condition):
    """Final height as a function of C_d.
    
    C_d: drag coefficient
    condition: Condition object
    
    returns: height in m
    """
    condition.set(C_d=C_d)
    system = make_system(condition)
    run_odeint(system, slope_func)
    y, v = final_state(system.results)
    return y

# %% [markdown]
# If we run it with `C_d=0.4`, we get -11 meters again.

# %%
height_func(0.4, condition)
# Out:
# <Quantity(-11.034779626277231, 'meter')>

# %% [markdown]
# Now we can use `fsolve` to find the value of `C_d` that makes the final height 0.

# %%
solution = fsolve(height_func, 0.4, condition)
solution
# Out:
# array([ 0.42587017])

# %% [markdown]
# Plugging in the estimated value, we can run the simulation again to get terminal velocity.

# %%
condition.set(C_d=solution)
system = make_system(condition)
run_odeint(system, slope_func)
final_state(system.results)
# Out:
# (<Quantity(-4.725109192804666e-13, 'meter')>,
#  <Quantity(-21.689751051700213, 'meter / second')>)

# %% [markdown]
# In this example, the terminal velocity of the quarter is higher than that of the penny, but we should not take this result seriously because the measurements we used are not real; I made them up.

# %%
"""neat"""
